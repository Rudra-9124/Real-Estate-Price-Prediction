# %% [markdown]
# # Real Estate Price Prediction

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('RealEstate.csv')
data.head()
# Out:
#    No  transaction date  house age  distance to the nearest MRT station  \
# 0   1          2012.917       32.0                             84.87882
# 1   2          2012.917       19.5                            306.59470
# 2   3          2013.583       13.3                            561.98450
# 3   4          2013.500       13.3                            561.98450
# 4   5          2012.833        5.0                            390.56840
#
#    number of convenience stores  latitude  longitude  house price of unit area
# 0                            10  24.98298  121.54024                      37.9
# 1                             9  24.98034  121.53951                      42.2
# 2                             5  24.98746  121.54391                      47.3
# 3                             5  24.98746  121.54391                      54.8
# 4                             5  24.97937  121.54245                      43.1

# %%
x = data.drop(['No','house price of unit area'], axis=1)
y = data[['house price of unit area']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1, test_size=0.2)

# %% [markdown]
# ## Linear Model

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
r2 = r2_score(y_test, y_pred)
print("R2 Score:", r2)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# R2 Score: 0.7034608498767305
# Mean Squared Error: 45.01050719519454
# Mean Absolute Error: 5.343030944663055

# %% [markdown]
# ## Polynomial Model

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
pl = PolynomialFeatures(degree=3)
x_poly_train = pl.fit_transform(x_train)
x_poly_test = pl.transform(x_test)

lr = LinearRegression()
lr.fit(x_poly_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_poly_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
r2 = r2_score(y_test, y_pred)
print("R2 Score:", r2)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# R2 Score: 0.7409917829996375
# Mean Squared Error: 39.31383498625098
# Mean Absolute Error: 4.8266635440559265
